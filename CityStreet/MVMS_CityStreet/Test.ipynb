# %%
import os 
import sys
import time
import h5py
import numpy as np
import tensorflow as tf
from tensorflow.keras.optimizers import SGD
from net_def import build_model_FCN_model_api as build_FCNN
from datagen_v3 import datagen_v3



import cv2
import matplotlib.pyplot as plt

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# set enough GPU memory as needed(default, all GPU memory is used)
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)

# %%
def build_model_load_weights(image_dim, model_dir, model_name):
    opt = SGD(
            lr=0.0001,
            decay=0.0001,
            momentum=0.9,
            nesterov=False,
            clipnorm=5,
            clipvalue=1)
    model = build_FCNN(
        batch_size=1,
        patch_size=image_dim,
        optimizer=opt,
        output_ROI_mask=False,
    )
    
    model.load_weights(filepath=os.path.join(model_dir,model_name),by_name=True)
    print(os.path.join(model_dir,model_name))
    return model

def main(exp_name):
    image_dim = (380, 676, 3)
    model_dir = './models/Street_all_output_{}'.format(exp_name)
    model_name = 'best.h5'
    
    train_path0 = '../../violation_data/'
    test_view1_1 = train_path0 + 'test/view1_violation.h5'
    test_view2_1 = train_path0 + 'test/view2_violation.h5'
    test_view3_1 = train_path0 + 'test/view3_violation.h5'
    test_GP_1 = train_path0 + 'test/gp_violations.h5'
    
    h5file_test_GP = [test_GP_1]

    h5file_test_view1 = [test_view1_1]
    h5file_test_view2 = [test_view2_1]
    h5file_test_view3 = [test_view3_1]

    test_gen = datagen_v3(
        h5file_view1=h5file_test_view1,
        h5file_view2=h5file_test_view2,
        h5file_view3=h5file_test_view3,
        h5file_GP=h5file_test_GP,

        batch_size=1,
        images_per_set=None,
        patches_per_image=1,  # 1000,
        patch_dim=image_dim[:2],
        density_scaler=1000,
        image_shuffle=True,
        patch_shuffle=True,
        random_state=None
    )
    
    model = build_model_load_weights(image_dim,model_dir,model_name)
    model.summary()
    
    result = model.predict(test_gen, verbose=1)
    
    return result

# %%
if __name__ == '__main__':
    main(exp_name='07210432')
# Out:
# Using build_model_FCN_model_api
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for LRN layer.
# No trainable weights for mask layer.
# No trainable weights for mask layer.
# No trainable weights for mask layer.
# Compiling ...
# ./models/Street_all_output_07210432\best.h5
# Model: "Multi-view_FCNoverall"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# patches1_s1 (InputLayer)        [(1, 190, 338, 3)]   0
# __________________________________________________________________________________________________
# patches1_s2 (InputLayer)        [(1, 95, 169, 3)]    0
# __________________________________________________________________________________________________
# patches2_s1 (InputLayer)        [(1, 190, 338, 3)]   0
# __________________________________________________________________________________________________
# patches2_s2 (InputLayer)        [(1, 95, 169, 3)]    0
# __________________________________________________________________________________________________
# patches3_s1 (InputLayer)        [(1, 190, 338, 3)]   0
# __________________________________________________________________________________________________
# patches3_s2 (InputLayer)        [(1, 95, 169, 3)]    0
# __________________________________________________________________________________________________
# patches1_s0 (InputLayer)        [(1, 380, 676, 3)]   0
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (1, 190, 338, 16)    1216        patches1_s1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (1, 95, 169, 16)     1216        patches1_s2[0][0]
# __________________________________________________________________________________________________
# patches2_s0 (InputLayer)        [(1, 380, 676, 3)]   0
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (1, 190, 338, 16)    1216        patches2_s1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (1, 95, 169, 16)     1216        patches2_s2[0][0]
# __________________________________________________________________________________________________
# patches3_s0 (InputLayer)        [(1, 380, 676, 3)]   0
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (1, 190, 338, 16)    1216        patches3_s1[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (1, 95, 169, 16)     1216        patches3_s2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (1, 380, 676, 16)    1216        patches1_s0[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (1, 190, 338, 16)    0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (1, 95, 169, 16)     0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (1, 380, 676, 16)    1216        patches2_s0[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (1, 190, 338, 16)    0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (1, 95, 169, 16)     0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (1, 380, 676, 16)    1216        patches3_s0[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (1, 190, 338, 16)    0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (1, 95, 169, 16)     0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (1, 380, 676, 16)    0           conv2d[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_4 (AcrossCha (1, 190, 338, 16)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_8 (AcrossCha (1, 95, 169, 16)     0           activation_8[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (1, 380, 676, 16)    0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_16 (AcrossCh (1, 190, 338, 16)    0           activation_16[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_20 (AcrossCh (1, 95, 169, 16)     0           activation_20[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (1, 380, 676, 16)    0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_28 (AcrossCh (1, 190, 338, 16)    0           activation_28[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_32 (AcrossCh (1, 95, 169, 16)     0           activation_32[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn (AcrossChann (1, 380, 676, 16)    0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (1, 190, 338, 16)    6416        across_channel_lrn_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (1, 95, 169, 16)     6416        across_channel_lrn_8[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_12 (AcrossCh (1, 380, 676, 16)    0           activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (1, 190, 338, 16)    6416        across_channel_lrn_16[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (1, 95, 169, 16)     6416        across_channel_lrn_20[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_24 (AcrossCh (1, 380, 676, 16)    0           activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (1, 190, 338, 16)    6416        across_channel_lrn_28[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (1, 95, 169, 16)     6416        across_channel_lrn_32[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (1, 380, 676, 16)    6416        across_channel_lrn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (1, 95, 169, 16)     0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (1, 48, 85, 16)      0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (1, 380, 676, 16)    6416        across_channel_lrn_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (1, 95, 169, 16)     0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (1, 48, 85, 16)      0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (1, 380, 676, 16)    6416        across_channel_lrn_24[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (1, 95, 169, 16)     0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (1, 48, 85, 16)      0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (1, 190, 338, 16)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (1, 95, 169, 16)     0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (1, 48, 85, 16)      0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (1, 190, 338, 16)    0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (1, 95, 169, 16)     0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (1, 48, 85, 16)      0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (1, 190, 338, 16)    0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (1, 95, 169, 16)     0           max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (1, 48, 85, 16)      0           max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (1, 190, 338, 16)    0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_5 (AcrossCha (1, 95, 169, 16)     0           activation_5[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_9 (AcrossCha (1, 48, 85, 16)      0           activation_9[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (1, 190, 338, 16)    0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_17 (AcrossCh (1, 95, 169, 16)     0           activation_17[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_21 (AcrossCh (1, 48, 85, 16)      0           activation_21[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (1, 190, 338, 16)    0           max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_29 (AcrossCh (1, 95, 169, 16)     0           activation_29[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_33 (AcrossCh (1, 48, 85, 16)      0           activation_33[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_1 (AcrossCha (1, 190, 338, 16)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (1, 95, 169, 32)     12832       across_channel_lrn_5[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (1, 48, 85, 32)      12832       across_channel_lrn_9[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_13 (AcrossCh (1, 190, 338, 16)    0           activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (1, 95, 169, 32)     12832       across_channel_lrn_17[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (1, 48, 85, 32)      12832       across_channel_lrn_21[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_25 (AcrossCh (1, 190, 338, 16)    0           activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (1, 95, 169, 32)     12832       across_channel_lrn_29[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (1, 48, 85, 32)      12832       across_channel_lrn_33[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (1, 190, 338, 32)    12832       across_channel_lrn_1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (1, 95, 169, 32)     0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (1, 48, 85, 32)      0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (1, 190, 338, 32)    12832       across_channel_lrn_13[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (1, 95, 169, 32)     0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (1, 48, 85, 32)      0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (1, 190, 338, 32)    12832       across_channel_lrn_25[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (1, 95, 169, 32)     0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (1, 48, 85, 32)      0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (1, 190, 338, 32)    0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_6 (AcrossCha (1, 95, 169, 32)     0           activation_6[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_10 (AcrossCh (1, 48, 85, 32)      0           activation_10[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (1, 190, 338, 32)    0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_18 (AcrossCh (1, 95, 169, 32)     0           activation_18[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_22 (AcrossCh (1, 48, 85, 32)      0           activation_22[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (1, 190, 338, 32)    0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_30 (AcrossCh (1, 95, 169, 32)     0           activation_30[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_34 (AcrossCh (1, 48, 85, 32)      0           activation_34[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_2 (AcrossCha (1, 190, 338, 32)    0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (1, 95, 169, 32)     25632       across_channel_lrn_6[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (1, 48, 85, 32)      25632       across_channel_lrn_10[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_14 (AcrossCh (1, 190, 338, 32)    0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (1, 95, 169, 32)     25632       across_channel_lrn_18[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (1, 48, 85, 32)      25632       across_channel_lrn_22[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_26 (AcrossCh (1, 190, 338, 32)    0           activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (1, 95, 169, 32)     25632       across_channel_lrn_30[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (1, 48, 85, 32)      25632       across_channel_lrn_34[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (1, 190, 338, 32)    25632       across_channel_lrn_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (1, 48, 85, 32)      0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (1, 24, 43, 32)      0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (1, 190, 338, 32)    25632       across_channel_lrn_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (1, 48, 85, 32)      0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (1, 24, 43, 32)      0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (1, 190, 338, 32)    25632       across_channel_lrn_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (1, 48, 85, 32)      0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (1, 24, 43, 32)      0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (1, 95, 169, 32)     0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (1, 48, 85, 32)      0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (1, 24, 43, 32)      0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (1, 95, 169, 32)     0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (1, 48, 85, 32)      0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (1, 24, 43, 32)      0           max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (1, 95, 169, 32)     0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (1, 48, 85, 32)      0           max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (1, 24, 43, 32)      0           max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (1, 95, 169, 32)     0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_7 (AcrossCha (1, 48, 85, 32)      0           activation_7[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_11 (AcrossCh (1, 24, 43, 32)      0           activation_11[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (1, 95, 169, 32)     0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_19 (AcrossCh (1, 48, 85, 32)      0           activation_19[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_23 (AcrossCh (1, 24, 43, 32)      0           activation_23[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (1, 95, 169, 32)     0           max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_31 (AcrossCh (1, 48, 85, 32)      0           activation_31[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_35 (AcrossCh (1, 24, 43, 32)      0           activation_35[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_3 (AcrossCha (1, 95, 169, 32)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (1, 48, 85, 32)      25632       across_channel_lrn_7[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (1, 24, 43, 32)      25632       across_channel_lrn_11[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_15 (AcrossCh (1, 95, 169, 32)     0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (1, 48, 85, 32)      25632       across_channel_lrn_19[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (1, 24, 43, 32)      25632       across_channel_lrn_23[0][0]
# __________________________________________________________________________________________________
# across_channel_lrn_27 (AcrossCh (1, 95, 169, 32)     0           activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (1, 48, 85, 32)      25632       across_channel_lrn_31[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (1, 24, 43, 32)      25632       across_channel_lrn_35[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (1, 95, 169, 32)     25632       across_channel_lrn_3[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (1, 48, 85, 32)      0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (1, 24, 43, 32)      0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# depth_ratio_v1 (InputLayer)     [(1, 95, 169, 1)]    0
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (1, 95, 169, 32)     25632       across_channel_lrn_15[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (1, 48, 85, 32)      0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (1, 24, 43, 32)      0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# depth_ratio_v2 (InputLayer)     [(1, 95, 169, 1)]    0
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (1, 95, 169, 32)     25632       across_channel_lrn_27[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (1, 48, 85, 32)      0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (1, 24, 43, 32)      0           conv2d_47[0][0]
# __________________________________________________________________________________________________
# depth_ratio_v3 (InputLayer)     [(1, 95, 169, 1)]    0
# __________________________________________________________________________________________________
# activation_36 (Activation)      (1, 95, 169, 32)     0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# up_sampling_layer (UpSampling_l (1, 95, 169, 32)     0           activation_37[0][0]
# __________________________________________________________________________________________________
# up_sampling_layer_1 (UpSampling (1, 95, 169, 32)     0           activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (1, 95, 169, 1)      2           depth_ratio_v1[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (1, 95, 169, 32)     0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# up_sampling_layer_2 (UpSampling (1, 95, 169, 32)     0           activation_40[0][0]
# __________________________________________________________________________________________________
# up_sampling_layer_3 (UpSampling (1, 95, 169, 32)     0           activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (1, 95, 169, 1)      2           depth_ratio_v2[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (1, 95, 169, 32)     0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# up_sampling_layer_4 (UpSampling (1, 95, 169, 32)     0           activation_43[0][0]
# __________________________________________________________________________________________________
# up_sampling_layer_5 (UpSampling (1, 95, 169, 32)     0           activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (1, 95, 169, 1)      2           depth_ratio_v3[0][0]
# __________________________________________________________________________________________________
# cat_map_v1 (Concatenate)        (1, 95, 169, 96)     0           activation_36[0][0]
#                                                                  up_sampling_layer[0][0]
#                                                                  up_sampling_layer_1[0][0]
# __________________________________________________________________________________________________
# feature_scale_fusion_layer_rbm  (1, 95, 169, 3)      0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# cat_map_v2 (Concatenate)        (1, 95, 169, 96)     0           activation_39[0][0]
#                                                                  up_sampling_layer_2[0][0]
#                                                                  up_sampling_layer_3[0][0]
# __________________________________________________________________________________________________
# feature_scale_fusion_layer_rbm_ (1, 95, 169, 3)      0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# cat_map_v3 (Concatenate)        (1, 95, 169, 96)     0           activation_42[0][0]
#                                                                  up_sampling_layer_4[0][0]
#                                                                  up_sampling_layer_5[0][0]
# __________________________________________________________________________________________________
# feature_scale_fusion_layer_rbm_ (1, 95, 169, 3)      0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# feature_scale_fusion_layer (fea (1, 95, 169, 32)     0           cat_map_v1[0][0]
#                                                                  feature_scale_fusion_layer_rbm[0]
# __________________________________________________________________________________________________
# feature_scale_fusion_layer_1 (f (1, 95, 169, 32)     0           cat_map_v2[0][0]
#                                                                  feature_scale_fusion_layer_rbm_1[
# __________________________________________________________________________________________________
# feature_scale_fusion_layer_2 (f (1, 95, 169, 32)     0           cat_map_v3[0][0]
#                                                                  feature_scale_fusion_layer_rbm_2[
# __________________________________________________________________________________________________
# spatial_transformer (SpatialTra (1, 192, 160, 32)    0           feature_scale_fusion_layer[0][0]
# __________________________________________________________________________________________________
# spatial_transformer_1 (SpatialT (1, 192, 160, 32)    0           feature_scale_fusion_layer_1[0][0
# __________________________________________________________________________________________________
# spatial_transformer_2 (SpatialT (1, 192, 160, 32)    0           feature_scale_fusion_layer_2[0][0
# __________________________________________________________________________________________________
# cat_map_fusion (Concatenate)    (1, 192, 160, 96)    0           spatial_transformer[0][0]
#                                                                  spatial_transformer_1[0][0]
#                                                                  spatial_transformer_2[0][0]
# __________________________________________________________________________________________________
# scale_fusion (Conv2D)           (1, 192, 160, 96)    9312        cat_map_fusion[0][0]
# __________________________________________________________________________________________________
# scale_fusion_act (Activation)   (1, 192, 160, 96)    0           scale_fusion[0][0]
# __________________________________________________________________________________________________
# conv_block_fusion1 (Conv2D)     (1, 192, 160, 64)    153664      scale_fusion_act[0][0]
# __________________________________________________________________________________________________
# conv_block_fusion1_act (Activat (1, 192, 160, 64)    0           conv_block_fusion1[0][0]
# __________________________________________________________________________________________________
# conv_block_fusion2 (Conv2D)     (1, 192, 160, 32)    51232       conv_block_fusion1_act[0][0]
# __________________________________________________________________________________________________
# conv_block_fusion2_act (Activat (1, 192, 160, 32)    0           conv_block_fusion2[0][0]
# __________________________________________________________________________________________________
# conv_block_fusion3 (Conv2D)     (1, 192, 160, 1)     801         conv_block_fusion2_act[0][0]
# __________________________________________________________________________________________________
# conv_block_fusion3_act (Activat (1, 192, 160, 1)     0           conv_block_fusion3[0][0]
# ==================================================================================================
# Total params: 860,567
# Trainable params: 860,567
# Non-trainable params: 0
# __________________________________________________________________________________________________
#      73/Unknown - 14s 194ms/step WARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.116736). Check your callbacks.
#     245/Unknown - 48s 198ms/step 48s 197ms/stWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.117168). Check your callbacks.
#     246/Unknown - 49s 197ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.122168). Check your callbacks.
#     385/Unknown - 76s 199ms/st - 76s 199ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.101526). Check your callbacks.
#     386/Unknown - 77s 199ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.117135). Check your callbacks.
#     387/Unknown - 77s 199ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.117135). Check your callbacks.
#     428/Unknown - 85s 199ms/step 83s 199m - 84s 199ms/st - 84s 19WARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.117159). Check your callbacks.
#     569/Unknown - 113s 199ms/step- 111WARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.105201). Check your callbacks.
#     571/Unknown - 114s 199ms/ste - 114s 199ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.101997). Check your callbacks.
#     572/Unknown - 114s 199ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.101997). Check your callbacks.
#     573/Unknown - 114s 199ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.101997). Check your callbacks.
#     828/Unknown - 179s 216ms/ste - 179s 216ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.102673). Check your callbacks.
#     884/Unknown - 191s 216ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.104618). Check your callbacks.
#     885/Unknown - 191s 215ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.104618). Check your callbacks.
#     886/Unknown - 191s 215ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.104618). Check your callbacks.
#     889/Unknown - 192s 215ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.104618). Check your callbacks.
#     961/Unknown - 206s 214ms/step- 206s 214ms/steWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.120666). Check your callbacks.
#     962/Unknown - 206s 214ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.120666). Check your callbacks.
#     965/Unknown - 207s 214ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.115181). Check your callbacks.
#     966/Unknown - 207s 214ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.115181). Check your callbacks.
#     967/Unknown - 207s 214ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.115181). Check your callbacks.
#    1019/Unknown - 217s 213ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.102713). Check your callbacks.
#    1022/Unknown - 218s 213ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.102215). Check your callbacks.
#    1036/Unknown - 221s 213ms/ste - 221s 213ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.107205). Check your callbacks.
#    1037/Unknown - 221s 213ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.107205). Check your callbacks.
#    1098/Unknown - 235s 214ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.108199). Check your callbacks.
#    1099/Unknown - 235s 214ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.108199). Check your callbacks.
#    1100/Unknown - 235s 214ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.108199). Check your callbacks.
#    1101/Unknown - 235s 214ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.100732). Check your callbacks.
#    1102/Unknown - 236s 214ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.100732). Check your callbacks.
#    1103/Unknown - 236s 214ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.100732). Check your callbacks.
#    1243/Unknown - 264s 212ms/step- 264s 212ms/stWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.114252). Check your callbacks.
#    1244/Unknown - 264s 212ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.114252). Check your callbacks.
#    1245/Unknown - 264s 212ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.114252). Check your callbacks.
#    1261/Unknown - 268s 212ms/step- 267s 212msWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.121164). Check your callbacks.
#    1262/Unknown - 268s 212ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.115678). Check your callbacks.
#    1263/Unknown - 268s 212ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.115678). Check your callbacks.
#    1264/Unknown - 268s 212ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.115678). Check your callbacks.
#    1266/Unknown - 268s 212ms/ste - 269s 212ms/stepWARNING:tensorflow:Method (on_predict_batch_end) is slow compared to the batch update (0.114682). Check your callbacks.
#    1280/Unknown - 271s 212ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-158dd1636fcf> in <module>
#       1 if __name__ == '__main__':
# ----> 2     main(exp_name='07210432')
#
# <ipython-input-2-5336e650a111> in main(exp_name)
#      54     model.summary()
#      55
# ---> 56     result = model.predict(test_gen, verbose=1)
#      57
#      58     return result
#
# c:\program files\python38\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#      86       raise ValueError('{} is not supported in multi-worker mode.'.format(
#      87           method.__name__))
# ---> 88     return method(self, *args, **kwargs)
#      89
#      90   return tf_decorator.make_decorator(
#
# c:\program files\python38\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1281                   lambda output, batch_output: output.append(batch_output),
#    1282                   outputs, batch_outputs)
# -> 1283             callbacks.on_predict_batch_end(step, {'outputs': batch_outputs})
#    1284       callbacks.on_predict_end()
#    1285     all_outputs = nest.map_structure_up_to(batch_outputs, concat, outputs)
#
# c:\program files\python38\lib\site-packages\tensorflow\python\keras\callbacks.py in on_predict_batch_end(self, batch, logs)
#     433     """
#     434     if self._should_call_predict_batch_hooks:
# --> 435       logs = self._process_logs(logs)
#     436       self._call_batch_hook(ModeKeys.PREDICT, 'end', batch, logs=logs)
#     437
#
# c:\program files\python38\lib\site-packages\tensorflow\python\keras\callbacks.py in _process_logs(self, logs)
#     263     """Turns tensors into numpy arrays or Python scalars."""
#     264     if logs:
# --> 265       return tf_utils.to_numpy_or_python_type(logs)
#     266     return {}
#     267
#
# c:\program files\python38\lib\site-packages\tensorflow\python\keras\utils\tf_utils.py in to_numpy_or_python_type(tensors)
#     521     return t  # Don't turn ragged or sparse tensors to NumPy.
#     522
# --> 523   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     524
#
# c:\program files\python38\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     615
#     616   return pack_sequence_as(
# --> 617       structure[0], [func(*x) for x in entries],
#     618       expand_composites=expand_composites)
#     619
#
# c:\program files\python38\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     615
#     616   return pack_sequence_as(
# --> 617       structure[0], [func(*x) for x in entries],
#     618       expand_composites=expand_composites)
#     619
#
# c:\program files\python38\lib\site-packages\tensorflow\python\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     517   def _to_single_numpy_or_python_type(t):
#     518     if isinstance(t, ops.Tensor):
# --> 519       x = t.numpy()
#     520       return x.item() if np.ndim(x) == 0 else x
#     521     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# c:\program files\python38\lib\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#     959     """
#     960     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 961     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     962     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     963
#
# c:\program files\python38\lib\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#     925     # pylint: disable=protected-access
#     926     try:
# --> 927       return self._numpy_internal()
#     928     except core._NotOkStatusException as e:
#     929       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:
